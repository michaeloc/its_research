# %%
import pandas as pd
import sys  
sys.path.insert(0, '../building_trajectories/')
import sentences
#%run '../building_trajectories/sentences.py'
import numpy as np
from tqdm import tqdm

#Spark
import findspark
findspark.init("../venvTraj/lib64/python3.8/site-packages/pyspark/")
from pyspark import SparkContext

# Bokeh

from bokeh.plotting import figure, show, output_notebook
from bokeh.tile_providers import get_provider, Vendors, OSM, CARTODBPOSITRON, WIKIMEDIA
import pandas as pd 
import math
from ast import literal_eval

output_notebook()
tile_provider = OSM
colors=['red','blue', 'black', 'yellow']
trajetoria = ['line_id','journey_id','time_frame','vehicle_journey_id','operator','vehicle_id']
features = ['timestamp','line_id','direction','journey_id',
            'time_frame','vehicle_journey_id','operator',
            'congestion','lng','lat','delay','block_id',
            'vehicle_id','stop_id', 'stop']
data_merged = pd.read_csv(
    '../data/siri.20130110.csv.gz', 
    compression='gzip', 
    names=features, 
    header=None)
for i in tqdm(range(20130111,20130112,1)):
    data = pd.read_csv(
        '../data/siri.'+str(i)+'.csv.gz', 
        compression='gzip', 
        names=features, 
        header=None)
    data_merged = pd.concat([data_merged,data])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# 100%|██████████| 1/1 [00:03<00:00,  3.58s/it]

# %%
def _has_min_quantity_of_points( items):
    return len(items) > 10

def is_window( delta_time):
    return delta_time < 5 * 60

def delta_time( t1, t2) -> float:
    ##Return time difference between time in seconds
    t1 = pd.to_datetime(t1,unit='us')
    t2 = pd.to_datetime(t2,unit='us')
    delta = pd.Timedelta(np.abs(t2 - t1))
    return delta.seconds

def is_valid_point( data, idx, actual_trajectory, trajectory_features):
    return all(data[trajectory_features].loc[idx] == actual_trajectory)

def create_sentences(data, trajectory_features) -> list:
    data = data.sort_values('timestamp')
    actual_trajectory = data[trajectory_features].iloc[0].values
    actual_time = data.iloc[0].timestamp
    partial_list, complete_trajectory = [], []
    iterator = 0
    for index in tqdm(data.index):
        if (is_valid_point(data, index, actual_trajectory,trajectory_features)):
            delta = delta_time(actual_time, data.loc[index].timestamp)
            if is_window(delta):
                partial_list.append(data.loc[index].tolist())
        actual_time = data.loc[index].timestamp
        iterator += 1
    if _has_min_quantity_of_points(partial_list):
        complete_trajectory.append(partial_list)
    return complete_trajectory

# %%
from sentences import Sentences
sentence = Sentences(data_merged, trajetoria)
# Out:
# 14439

# %%
data_merged = sentence.preprocess.clean_data(data_merged)

# %%
sc = SparkContext()

# %%
dfs = [x for _, x in data_merged.groupby(trajetoria)]

# %%
#A=sc.parallelize(c=sentence.trejectories)
A=sc.parallelize(dfs)

# %%
#query = "(line_id == {}) & (journey_id == '{}') & (time_frame == '{}')  & (vehicle_journey_id == '{}') & (operator == '{}') & (vehicle_id == {})"
#B = A.map(lambda x: sentence.create_sentences(sentence.data.query(query.format(*chave))))
B = A.map(lambda x: create_sentences(x, trajetoria))

# %%
# %%timeit

B.collect()
print('-')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-adb2831a8aa0> in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', "\nB.collect()\nprint('-')\n")
#
# ~/hd/projetos/trajetorias/its_research/venvTraj/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2379             with self.builtin_trap:
#    2380                 args = (magic_arg_s, cell)
# -> 2381                 result = fn(*args, **kwargs)
#    2382             return result
#    2383
#
# <decorator-gen-53> in timeit(self, line, cell, local_ns)
#
# ~/hd/projetos/trajetorias/its_research/venvTraj/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...

# %% [raw]
# complete = [sentence.create_sentences(sentence.data.query(query.format(*chave)))
#                                                      for chave in sentence.trejectories]
